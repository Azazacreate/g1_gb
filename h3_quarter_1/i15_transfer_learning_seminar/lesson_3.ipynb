# %%
from transformers import pipeline


classifier = pipeline("sentiment-analysis", model="blanchefort/rubert-base-cased-sentiment")
texts = [
    "Отличный товар",
    "Мне не понравилось",
    "Прекрасно выглядит, ничего не меняйте!",
    "Ничего не понял",
    "У меня не работала розетка, в остальном все отлично"
]
predictions = classifier(texts)


for text, prediction in zip(texts, predictions):
    print(f"Текст: {text} | Предсказание: {prediction}")
# Out:
# config.json:   0%|          | 0.00/943 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/499 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# Текст: Отличный товар | Предсказание: {'label': 'POSITIVE', 'score': 0.9768824577331543}
# Текст: Мне не понравилось | Предсказание: {'label': 'NEUTRAL', 'score': 0.6234394907951355}
# Текст: Прекрасно выглядит, ничего не меняйте! | Предсказание: {'label': 'NEGATIVE', 'score': 0.7515069842338562}
# Текст: Ничего не понял | Предсказание: {'label': 'NEUTRAL', 'score': 0.8207123279571533}
# Текст: У меня не работала розетка, в остальном все отлично | Предсказание: {'label': 'POSITIVE', 'score': 0.9771335124969482}
