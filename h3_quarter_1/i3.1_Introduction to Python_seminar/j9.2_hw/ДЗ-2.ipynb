# %% [markdown]
# ## ДЗ-2
#
# Задание 1.
# Загрузите таблицу из файла advertising_1.csv и сохраните её в датафрейм adv1_df. Укажите в качестве индекса столбец Number. Выведите на экран первые десять строк.
#
# Задание 2.
# Выведите размер датафрейма adv1_df и cреднее ежедневное время нахождения в интернете пользователя под номером 8.
#
# Задание 3.
# Загрузите таблицу из файла advertising_2.csv и сохраните её в датафрейм adv2_df. Укажите в качестве индекса стоблец Number. Выведите на экран строки для пользователей с номерами с 533-го по 536-й.

# %%
import pandas as pd
df
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# ...                          ...                   ...
# 525                        46.61                136.18
# 526                        63.26                120.46
# 527                        79.16                202.90
# 528                        67.94                128.16
# 529                        79.91                230.18
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# ...

# %%
df = pd.read_csv("advertising_1.csv")
df = df.set_index("Number")
df.head(10)
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# 11                         88.91                208.36
# 12                           NaN                131.76
# 13                         74.53                   NaN
# 14                         69.88                183.82
# 15                         47.64                122.02
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# 9               Robust logistical utilization              0
# ...

# %%
# Вариант-2
df = pd.read_csv("advertising_1.csv", index_col="Number")
df.head(10)
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# 11                         88.91                208.36
# 12                           NaN                131.76
# 13                         74.53                   NaN
# 14                         69.88                183.82
# 15                         47.64                122.02
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# 9               Robust logistical utilization              0
# ...

# %% [markdown]
# ### task-2

# %%
df.shape
# Out:
# (500, 4)

# %%
df.loc[8, "Daily Internet Usage"]
# Out:
# 245.89

# %%
# Вариант-2. Доступ по-индексу:числовому.

df.iloc[2, 1]
# Out:
# 245.89

# %% [markdown]
# ## task-3

# %%
df_adv2 = pd.read_csv("advertising_2.csv", index_col="Number")
df_adv2
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 530                          NaN                165.27
# 531                        43.65                   NaN
# 532                        59.61                198.45
# 533                        46.61                   NaN
# 534                          NaN                162.03
# ...                          ...                   ...
# 735                        65.53                190.17
# 736                        61.87                   NaN
# 737                        83.16                   NaN
# 738                        44.11                121.24
# 739                        56.57                131.98
#
#                                        Ad Topic Line  Clicked on Ad
# Number
# 530                 Re-engineered impactful software              0
# 531              Business-focused background synergy              1
# 532     Future-proofed coherent budgetary management              0
# ...

# %%
df_adv2.loc[533:536]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1

# %%
df_adv2.iloc[3:7]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1

# %% [markdown]
# # Tend.
