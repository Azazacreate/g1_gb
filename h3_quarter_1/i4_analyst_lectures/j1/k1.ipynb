# %%
print("Hsdfds")
# Out:
# Hsdfds

# %%
import pandas
pandas.__version__
# Out:
# '1.1.2'

# %%
import seaborn as sns
import numpy as np

x = np.random.randn(50)
sns.displot(x, bins=10);

# %% [markdown]
# ## dsfjkfkds
